# %% [markdown]
# <a href="https://colab.research.google.com/github/ravi-gopalan/dog_breed_classifier_udacity/blob/master/PyTorch_Transfer_Learning_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Transfer Learning
#
# In this notebook, you'll learn how to use pre-trained networks to solved challenging problems in computer vision. Specifically, you'll use networks trained on [ImageNet](http://www.image-net.org/) [available from torchvision](http://pytorch.org/docs/0.3.0/torchvision/models.html).
#
# ImageNet is a massive dataset with over 1 million labeled images in 1000 categories. It's used to train deep neural networks using an architecture called convolutional layers. I'm not going to get into the details of convolutional networks here, but if you want to learn more about them, please [watch this](https://www.youtube.com/watch?v=2-Ol7ZB0MmU).
#
# Once trained, these models work astonishingly well as feature detectors for images they weren't trained on. Using a pre-trained network on images not in the training set is called transfer learning. Here we'll use transfer learning to train a network that can classify our cat and dog photos with near perfect accuracy.
#
# With `torchvision.models` you can download these pre-trained networks and use them in your applications. We'll include `models` in our imports now.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
cd /root
# Out:
# /root

# %%
# !mkdir .kaggle

# %%
# !cp '/content/gdrive/My Drive/Colab_stuff/kaggle.json' /root/.kaggle/kaggle.json
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !ls

# %%
cd /content
# Out:
# /content

# %%
# !kaggle competitions download -c dogs-vs-cats
# Out:
# 404 - Not Found

# %%
# !unzip -q /content/train.zip

# %%
# !ls
# Out:
# gdrive	sample_data  sampleSubmission.csv  test1.zip  train  train.zip

# %%
cd /content/train
# Out:
# /content/train

# %%
# organize dataset into a useful structure
from os import makedirs
from os import listdir
from shutil import copyfile
from random import seed
from random import random
# create directories
dataset_home = '/content'
subdirs = ['train/', 'test/']
for subdir in subdirs:
	# create label subdirectories
	labeldirs = ['dogs/', 'cats/']
	for labldir in labeldirs:
		newdir = dataset_home + subdir + labldir
		makedirs(newdir, exist_ok=True)

# %%
# seed random number generator
seed(1)
# define ratio of pictures to use for validation
val_ratio = 0.25
# copy training dataset images into subdirectories
src_directory = '/content/train/'
for file in listdir(src_directory):
	src = src_directory + '/' + file
	dst_dir = 'train/'
	if random() < val_ratio:
		dst_dir = 'test/'
	if file.startswith('cat'):
		dst = dataset_home + dst_dir + 'cats/'  + file
		copyfile(src, dst)
	elif file.startswith('dog'):
		dst = dataset_home + dst_dir + 'dogs/'  + file
		copyfile(src, dst)

# %%
# !mkdir cat
# !mkdir dog

# %%
cd /content
# Out:
# /content

# %%
# !mkdir test

# %%
cd /content/test
# Out:
# /content/test

# %%
# !mkdir cat
# !mkdir dog

# %%
cd /content/train
# Out:
# /content/train

# %%
import os

# %%
base_dir = '/content'
train_cat_dir = '/content/train/cats'
train_dog_dir = '/content/train/dogs'
test_cat_dir = '/content/test/cats'
test_dog_dir = '/content/test/dogs'

# %%
print(len(listdir(train_cat_dir)))
print(len(listdir(train_dog_dir)))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-f4fae19dc160> in <module>()
# ----> 1 print(len(listdir(train_cat_dir)))
#       2 print(len(listdir(train_dog_dir)))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/train/cats'

# %%
# !bash -c 'mv cat*.jpg /content/train/cat'
# !bash -c 'mv dog*.jpg /content/train/dog'

# %%
cd /content/test1
# Out:
# /content/test1

# %%
# !bash -c 'mv cat*.jpg /content/test/cat'
# !bash -c 'mv dog*.jpg /content/test/dog'
# Out:
# mv: cannot stat 'cat*.jpg': No such file or directory
# mv: cannot stat 'dog*.jpg': No such file or directory

# %%
# !mkdir test

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt

import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torchvision import datasets, transforms, models

# %%
# !bash -c 'mv cat.{0..499}.jpg /content/test/cat'
# !bash -c 'mv dog.{0..499}.jpg /content/test/dog'
# Out:
# mv: cannot stat 'cat.0.jpg': No such file or directory
# mv: cannot stat 'cat.1.jpg': No such file or directory
# mv: cannot stat 'cat.2.jpg': No such file or directory
# mv: cannot stat 'cat.3.jpg': No such file or directory
# mv: cannot stat 'cat.4.jpg': No such file or directory
# mv: cannot stat 'cat.5.jpg': No such file or directory
# mv: cannot stat 'cat.6.jpg': No such file or directory
# mv: cannot stat 'cat.7.jpg': No such file or directory
# mv: cannot stat 'cat.8.jpg': No such file or directory
# mv: cannot stat 'cat.9.jpg': No such file or directory
# mv: cannot stat 'cat.10.jpg': No such file or directory
# mv: cannot stat 'cat.11.jpg': No such file or directory
# mv: cannot stat 'cat.12.jpg': No such file or directory
# mv: cannot stat 'cat.13.jpg': No such file or directory
# mv: cannot stat 'cat.14.jpg': No such file or directory
# mv: cannot stat 'cat.15.jpg': No such file or directory
# mv: cannot stat 'cat.16.jpg': No such file or directory
# mv: cannot stat 'cat.17.jpg': No such file or directory
# mv: cannot stat 'cat.18.jpg': No such file or directory
# mv: cannot stat 'cat.19.jpg': No such file or directory
# mv: cannot stat 'cat.20.jpg': No such file or directory
# mv: cannot stat 'cat.21.jpg': No such file or directory
# mv: cannot stat 'cat.22.jpg': No such file or directory
# mv: cannot stat 'cat.23.jpg': No such file or directory
# mv: cannot stat 'cat.24.jpg': No such file or directory
# mv: cannot stat 'cat.25.jpg': No such file or directory
# mv: cannot stat 'cat.26.jpg': No such file or directory
# mv: cannot stat 'cat.27.jpg': No such file or directory
# mv: cannot stat 'cat.28.jpg': No such file or directory
# mv: cannot stat 'cat.29.jpg': No such file or directory
# mv: cannot stat 'cat.30.jpg': No such file or directory
# mv: cannot stat 'cat.31.jpg': No such file or directory
# mv: cannot stat 'cat.32.jpg': No such file or directory
# mv: cannot stat 'cat.33.jpg': No such file or directory
# mv: cannot stat 'cat.34.jpg': No such file or directory
# mv: cannot stat 'cat.35.jpg': No such file or directory
# mv: cannot stat 'cat.36.jpg': No such file or directory
# mv: cannot stat 'cat.37.jpg': No such file or directory
# mv: cannot stat 'cat.38.jpg': No such file or directory
# mv: cannot stat 'cat.39.jpg': No such file or directory
# mv: cannot stat 'cat.40.jpg': No such file or directory
# mv: cannot stat 'cat.41.jpg': No such file or directory
# mv: cannot stat 'cat.42.jpg': No such file or directory
# mv: cannot stat 'cat.43.jpg': No such file or directory
# mv: cannot stat 'cat.44.jpg': No such file or directory
# mv: cannot stat 'cat.45.jpg': No such file or directory
# mv: cannot stat 'cat.46.jpg': No such file or directory
# mv: cannot stat 'cat.47.jpg': No such file or directory
# mv: cannot stat 'cat.48.jpg': No such file or directory
# mv: cannot stat 'cat.49.jpg': No such file or directory
# mv: cannot stat 'cat.50.jpg': No such file or directory
# mv: cannot stat 'cat.51.jpg': No such file or directory
# mv: cannot stat 'cat.52.jpg': No such file or directory
# mv: cannot stat 'cat.53.jpg': No such file or directory
# mv: cannot stat 'cat.54.jpg': No such file or directory
# mv: cannot stat 'cat.55.jpg': No such file or directory
# mv: cannot stat 'cat.56.jpg': No such file or directory
# mv: cannot stat 'cat.57.jpg': No such file or directory
# mv: cannot stat 'cat.58.jpg': No such file or directory
# mv: cannot stat 'cat.59.jpg': No such file or directory
# mv: cannot stat 'cat.60.jpg': No such file or directory
# mv: cannot stat 'cat.61.jpg': No such file or directory
# mv: cannot stat 'cat.62.jpg': No such file or directory
# mv: cannot stat 'cat.63.jpg': No such file or directory
# mv: cannot stat 'cat.64.jpg': No such file or directory
# mv: cannot stat 'cat.65.jpg': No such file or directory
# mv: cannot stat 'cat.66.jpg': No such file or directory
# mv: cannot stat 'cat.67.jpg': No such file or directory
# mv: cannot stat 'cat.68.jpg': No such file or directory
# mv: cannot stat 'cat.69.jpg': No such file or directory
# mv: cannot stat 'cat.70.jpg': No such file or directory
# mv: cannot stat 'cat.71.jpg': No such file or directory
# mv: cannot stat 'cat.72.jpg': No such file or directory
# mv: cannot stat 'cat.73.jpg': No such file or directory
# mv: cannot stat 'cat.74.jpg': No such file or directory
# mv: cannot stat 'cat.75.jpg': No such file or directory
# mv: cannot stat 'cat.76.jpg': No such file or directory
# mv: cannot stat 'cat.77.jpg': No such file or directory
# mv: cannot stat 'cat.78.jpg': No such file or directory
# mv: cannot stat 'cat.79.jpg': No such file or directory
# mv: cannot stat 'cat.80.jpg': No such file or directory
# mv: cannot stat 'cat.81.jpg': No such file or directory
# mv: cannot stat 'cat.82.jpg': No such file or directory
# mv: cannot stat 'cat.83.jpg': No such file or directory
# mv: cannot stat 'cat.84.jpg': No such file or directory
# mv: cannot stat 'cat.85.jpg': No such file or directory
# mv: cannot stat 'cat.86.jpg': No such file or directory
# mv: cannot stat 'cat.87.jpg': No such file or directory
# mv: cannot stat 'cat.88.jpg': No such file or directory
# mv: cannot stat 'cat.89.jpg': No such file or directory
# mv: cannot stat 'cat.90.jpg': No such file or directory
# mv: cannot stat 'cat.91.jpg': No such file or directory
# mv: cannot stat 'cat.92.jpg': No such file or directory
# mv: cannot stat 'cat.93.jpg': No such file or directory
# mv: cannot stat 'cat.94.jpg': No such file or directory
# mv: cannot stat 'cat.95.jpg': No such file or directory
# mv: cannot stat 'cat.96.jpg': No such file or directory
# mv: cannot stat 'cat.97.jpg': No such file or directory
# mv: cannot stat 'cat.98.jpg': No such file or directory
# mv: cannot stat 'cat.99.jpg': No such file or directory
# mv: cannot stat 'cat.100.jpg': No such file or directory
# mv: cannot stat 'cat.101.jpg': No such file or directory
# mv: cannot stat 'cat.102.jpg': No such file or directory
# mv: cannot stat 'cat.103.jpg': No such file or directory
# mv: cannot stat 'cat.104.jpg': No such file or directory
# mv: cannot stat 'cat.105.jpg': No such file or directory
# mv: cannot stat 'cat.106.jpg': No such file or directory
# mv: cannot stat 'cat.107.jpg': No such file or directory
# mv: cannot stat 'cat.108.jpg': No such file or directory
# mv: cannot stat 'cat.109.jpg': No such file or directory
# mv: cannot stat 'cat.110.jpg': No such file or directory
# mv: cannot stat 'cat.111.jpg': No such file or directory
# mv: cannot stat 'cat.112.jpg': No such file or directory
# mv: cannot stat 'cat.113.jpg': No such file or directory
# mv: cannot stat 'cat.114.jpg': No such file or directory
# mv: cannot stat 'cat.115.jpg': No such file or directory
# mv: cannot stat 'cat.116.jpg': No such file or directory
# mv: cannot stat 'cat.117.jpg': No such file or directory
# mv: cannot stat 'cat.118.jpg': No such file or directory
# mv: cannot stat 'cat.119.jpg': No such file or directory
# mv: cannot stat 'cat.120.jpg': No such file or directory
# mv: cannot stat 'cat.121.jpg': No such file or directory
# mv: cannot stat 'cat.122.jpg': No such file or directory
# mv: cannot stat 'cat.123.jpg': No such file or directory
# mv: cannot stat 'cat.124.jpg': No such file or directory
# mv: cannot stat 'cat.125.jpg': No such file or directory
# mv: cannot stat 'cat.126.jpg': No such file or directory
# mv: cannot stat 'cat.127.jpg': No such file or directory
# mv: cannot stat 'cat.128.jpg': No such file or directory
# mv: cannot stat 'cat.129.jpg': No such file or directory
# mv: cannot stat 'cat.130.jpg': No such file or directory
# mv: cannot stat 'cat.131.jpg': No such file or directory
# mv: cannot stat 'cat.132.jpg': No such file or directory
# mv: cannot stat 'cat.133.jpg': No such file or directory
# mv: cannot stat 'cat.134.jpg': No such file or directory
# mv: cannot stat 'cat.135.jpg': No such file or directory
# mv: cannot stat 'cat.136.jpg': No such file or directory
# mv: cannot stat 'cat.137.jpg': No such file or directory
# mv: cannot stat 'cat.138.jpg': No such file or directory
# mv: cannot stat 'cat.139.jpg': No such file or directory
# mv: cannot stat 'cat.140.jpg': No such file or directory
# mv: cannot stat 'cat.141.jpg': No such file or directory
# mv: cannot stat 'cat.142.jpg': No such file or directory
# mv: cannot stat 'cat.143.jpg': No such file or directory
# mv: cannot stat 'cat.144.jpg': No such file or directory
# mv: cannot stat 'cat.145.jpg': No such file or directory
# mv: cannot stat 'cat.146.jpg': No such file or directory
# mv: cannot stat 'cat.147.jpg': No such file or directory
# mv: cannot stat 'cat.148.jpg': No such file or directory
# mv: cannot stat 'cat.149.jpg': No such file or directory
# mv: cannot stat 'cat.150.jpg': No such file or directory
# mv: cannot stat 'cat.151.jpg': No such file or directory
# mv: cannot stat 'cat.152.jpg': No such file or directory
# mv: cannot stat 'cat.153.jpg': No such file or directory
# mv: cannot stat 'cat.154.jpg': No such file or directory
# mv: cannot stat 'cat.155.jpg': No such file or directory
# mv: cannot stat 'cat.156.jpg': No such file or directory
# mv: cannot stat 'cat.157.jpg': No such file or directory
# mv: cannot stat 'cat.158.jpg': No such file or directory
# mv: cannot stat 'cat.159.jpg': No such file or directory
# mv: cannot stat 'cat.160.jpg': No such file or directory
# mv: cannot stat 'cat.161.jpg': No such file or directory
# mv: cannot stat 'cat.162.jpg': No such file or directory
# mv: cannot stat 'cat.163.jpg': No such file or directory
# mv: cannot stat 'cat.164.jpg': No such file or directory
# mv: cannot stat 'cat.165.jpg': No such file or directory
# mv: cannot stat 'cat.166.jpg': No such file or directory
# mv: cannot stat 'cat.167.jpg': No such file or directory
# mv: cannot stat 'cat.168.jpg': No such file or directory
# mv: cannot stat 'cat.169.jpg': No such file or directory
# mv: cannot stat 'cat.170.jpg': No such file or directory
# mv: cannot stat 'cat.171.jpg': No such file or directory
# mv: cannot stat 'cat.172.jpg': No such file or directory
# mv: cannot stat 'cat.173.jpg': No such file or directory
# mv: cannot stat 'cat.174.jpg': No such file or directory
# mv: cannot stat 'cat.175.jpg': No such file or directory
# mv: cannot stat 'cat.176.jpg': No such file or directory
# mv: cannot stat 'cat.177.jpg': No such file or directory
# mv: cannot stat 'cat.178.jpg': No such file or directory
# mv: cannot stat 'cat.179.jpg': No such file or directory
# mv: cannot stat 'cat.180.jpg': No such file or directory
# mv: cannot stat 'cat.181.jpg': No such file or directory
# mv: cannot stat 'cat.182.jpg': No such file or directory
# mv: cannot stat 'cat.183.jpg': No such file or directory
# mv: cannot stat 'cat.184.jpg': No such file or directory
# mv: cannot stat 'cat.185.jpg': No such file or directory
# mv: cannot stat 'cat.186.jpg': No such file or directory
# mv: cannot stat 'cat.187.jpg': No such file or directory
# mv: cannot stat 'cat.188.jpg': No such file or directory
# mv: cannot stat 'cat.189.jpg': No such file or directory
# mv: cannot stat 'cat.190.jpg': No such file or directory
# mv: cannot stat 'cat.191.jpg': No such file or directory
# mv: cannot stat 'cat.192.jpg': No such file or directory
# mv: cannot stat 'cat.193.jpg': No such file or directory
# mv: cannot stat 'cat.194.jpg': No such file or directory
# mv: cannot stat 'cat.195.jpg': No such file or directory
# mv: cannot stat 'cat.196.jpg': No such file or directory
# mv: cannot stat 'cat.197.jpg': No such file or directory
# mv: cannot stat 'cat.198.jpg': No such file or directory
# mv: cannot stat 'cat.199.jpg': No such file or directory
# mv: cannot stat 'cat.200.jpg': No such file or directory
# mv: cannot stat 'cat.201.jpg': No such file or directory
# mv: cannot stat 'cat.202.jpg': No such file or directory
# mv: cannot stat 'cat.203.jpg': No such file or directory
# mv: cannot stat 'cat.204.jpg': No such file or directory
# mv: cannot stat 'cat.205.jpg': No such file or directory
# mv: cannot stat 'cat.206.jpg': No such file or directory
# mv: cannot stat 'cat.207.jpg': No such file or directory
# mv: cannot stat 'cat.208.jpg': No such file or directory
# mv: cannot stat 'cat.209.jpg': No such file or directory
# mv: cannot stat 'cat.210.jpg': No such file or directory
# mv: cannot stat 'cat.211.jpg': No such file or directory
# mv: cannot stat 'cat.212.jpg': No such file or directory
# mv: cannot stat 'cat.213.jpg': No such file or directory
# mv: cannot stat 'cat.214.jpg': No such file or directory
# mv: cannot stat 'cat.215.jpg': No such file or directory
# mv: cannot stat 'cat.216.jpg': No such file or directory
# mv: cannot stat 'cat.217.jpg': No such file or directory
# mv: cannot stat 'cat.218.jpg': No such file or directory
# mv: cannot stat 'cat.219.jpg': No such file or directory
# mv: cannot stat 'cat.220.jpg': No such file or directory
# mv: cannot stat 'cat.221.jpg': No such file or directory
# mv: cannot stat 'cat.222.jpg': No such file or directory
# mv: cannot stat 'cat.223.jpg': No such file or directory
# mv: cannot stat 'cat.224.jpg': No such file or directory
# mv: cannot stat 'cat.225.jpg': No such file or directory
# mv: cannot stat 'cat.226.jpg': No such file or directory
# mv: cannot stat 'cat.227.jpg': No such file or directory
# mv: cannot stat 'cat.228.jpg': No such file or directory
# mv: cannot stat 'cat.229.jpg': No such file or directory
# mv: cannot stat 'cat.230.jpg': No such file or directory
# mv: cannot stat 'cat.231.jpg': No such file or directory
# mv: cannot stat 'cat.232.jpg': No such file or directory
# mv: cannot stat 'cat.233.jpg': No such file or directory
# mv: cannot stat 'cat.234.jpg': No such file or directory
# mv: cannot stat 'cat.235.jpg': No such file or directory
# mv: cannot stat 'cat.236.jpg': No such file or directory
# mv: cannot stat 'cat.237.jpg': No such file or directory
# mv: cannot stat 'cat.238.jpg': No such file or directory
# mv: cannot stat 'cat.239.jpg': No such file or directory
# mv: cannot stat 'cat.240.jpg': No such file or directory
# mv: cannot stat 'cat.241.jpg': No such file or directory
# mv: cannot stat 'cat.242.jpg': No such file or directory
# mv: cannot stat 'cat.243.jpg': No such file or directory
# mv: cannot stat 'cat.244.jpg': No such file or directory
# mv: cannot stat 'cat.245.jpg': No such file or directory
# mv: cannot stat 'cat.246.jpg': No such file or directory
# mv: cannot stat 'cat.247.jpg': No such file or directory
# mv: cannot stat 'cat.248.jpg': No such file or directory
# mv: cannot stat 'cat.249.jpg': No such file or directory
# mv: cannot stat 'cat.250.jpg': No such file or directory
# mv: cannot stat 'cat.251.jpg': No such file or directory
# mv: cannot stat 'cat.252.jpg': No such file or directory
# mv: cannot stat 'cat.253.jpg': No such file or directory
# mv: cannot stat 'cat.254.jpg': No such file or directory
# mv: cannot stat 'cat.255.jpg': No such file or directory
# mv: cannot stat 'cat.256.jpg': No such file or directory
# mv: cannot stat 'cat.257.jpg': No such file or directory
# mv: cannot stat 'cat.258.jpg': No such file or directory
# mv: cannot stat 'cat.259.jpg': No such file or directory
# mv: cannot stat 'cat.260.jpg': No such file or directory
# mv: cannot stat 'cat.261.jpg': No such file or directory
# mv: cannot stat 'cat.262.jpg': No such file or directory
# mv: cannot stat 'cat.263.jpg': No such file or directory
# mv: cannot stat 'cat.264.jpg': No such file or directory
# mv: cannot stat 'cat.265.jpg': No such file or directory
# mv: cannot stat 'cat.266.jpg': No such file or directory
# mv: cannot stat 'cat.267.jpg': No such file or directory
# mv: cannot stat 'cat.268.jpg': No such file or directory
# mv: cannot stat 'cat.269.jpg': No such file or directory
# mv: cannot stat 'cat.270.jpg': No such file or directory
# mv: cannot stat 'cat.271.jpg': No such file or directory
# mv: cannot stat 'cat.272.jpg': No such file or directory
# mv: cannot stat 'cat.273.jpg': No such file or directory
# mv: cannot stat 'cat.274.jpg': No such file or directory
# mv: cannot stat 'cat.275.jpg': No such file or directory
# mv: cannot stat 'cat.276.jpg': No such file or directory
# mv: cannot stat 'cat.277.jpg': No such file or directory
# mv: cannot stat 'cat.278.jpg': No such file or directory
# mv: cannot stat 'cat.279.jpg': No such file or directory
# mv: cannot stat 'cat.280.jpg': No such file or directory
# mv: cannot stat 'cat.281.jpg': No such file or directory
# mv: cannot stat 'cat.282.jpg': No such file or directory
# mv: cannot stat 'cat.283.jpg': No such file or directory
# mv: cannot stat 'cat.284.jpg': No such file or directory
# mv: cannot stat 'cat.285.jpg': No such file or directory
# mv: cannot stat 'cat.286.jpg': No such file or directory
# mv: cannot stat 'cat.287.jpg': No such file or directory
# mv: cannot stat 'cat.288.jpg': No such file or directory
# mv: cannot stat 'cat.289.jpg': No such file or directory
# mv: cannot stat 'cat.290.jpg': No such file or directory
# mv: cannot stat 'cat.291.jpg': No such file or directory
# mv: cannot stat 'cat.292.jpg': No such file or directory
# mv: cannot stat 'cat.293.jpg': No such file or directory
# mv: cannot stat 'cat.294.jpg': No such file or directory
# mv: cannot stat 'cat.295.jpg': No such file or directory
# mv: cannot stat 'cat.296.jpg': No such file or directory
# mv: cannot stat 'cat.297.jpg': No such file or directory
# mv: cannot stat 'cat.298.jpg': No such file or directory
# mv: cannot stat 'cat.299.jpg': No such file or directory
# mv: cannot stat 'cat.300.jpg': No such file or directory
# mv: cannot stat 'cat.301.jpg': No such file or directory
# mv: cannot stat 'cat.302.jpg': No such file or directory
# mv: cannot stat 'cat.303.jpg': No such file or directory
# mv: cannot stat 'cat.304.jpg': No such file or directory
# mv: cannot stat 'cat.305.jpg': No such file or directory
# mv: cannot stat 'cat.306.jpg': No such file or directory
# mv: cannot stat 'cat.307.jpg': No such file or directory
# mv: cannot stat 'cat.308.jpg': No such file or directory
# mv: cannot stat 'cat.309.jpg': No such file or directory
# mv: cannot stat 'cat.310.jpg': No such file or directory
# mv: cannot stat 'cat.311.jpg': No such file or directory
# mv: cannot stat 'cat.312.jpg': No such file or directory
# mv: cannot stat 'cat.313.jpg': No such file or directory
# mv: cannot stat 'cat.314.jpg': No such file or directory
# mv: cannot stat 'cat.315.jpg': No such file or directory
# mv: cannot stat 'cat.316.jpg': No such file or directory
# mv: cannot stat 'cat.317.jpg': No such file or directory
# mv: cannot stat 'cat.318.jpg': No such file or directory
# mv: cannot stat 'cat.319.jpg': No such file or directory
# mv: cannot stat 'cat.320.jpg': No such file or directory
# mv: cannot stat 'cat.321.jpg': No such file or directory
# mv: cannot stat 'cat.322.jpg': No such file or directory
# mv: cannot stat 'cat.323.jpg': No such file or directory
# mv: cannot stat 'cat.324.jpg': No such file or directory
# mv: cannot stat 'cat.325.jpg': No such file or directory
# mv: cannot stat 'cat.326.jpg': No such file or directory
# mv: cannot stat 'cat.327.jpg': No such file or directory
# mv: cannot stat 'cat.328.jpg': No such file or directory
# mv: cannot stat 'cat.329.jpg': No such file or directory
# mv: cannot stat 'cat.330.jpg': No such file or directory
# mv: cannot stat 'cat.331.jpg': No such file or directory
# mv: cannot stat 'cat.332.jpg': No such file or directory
# mv: cannot stat 'cat.333.jpg': No such file or directory
# mv: cannot stat 'cat.334.jpg': No such file or directory
# mv: cannot stat 'cat.335.jpg': No such file or directory
# mv: cannot stat 'cat.336.jpg': No such file or directory
# mv: cannot stat 'cat.337.jpg': No such file or directory
# mv: cannot stat 'cat.338.jpg': No such file or directory
# mv: cannot stat 'cat.339.jpg': No such file or directory
# mv: cannot stat 'cat.340.jpg': No such file or directory
# mv: cannot stat 'cat.341.jpg': No such file or directory
# mv: cannot stat 'cat.342.jpg': No such file or directory
# mv: cannot stat 'cat.343.jpg': No such file or directory
# mv: cannot stat 'cat.344.jpg': No such file or directory
# mv: cannot stat 'cat.345.jpg': No such file or directory
# mv: cannot stat 'cat.346.jpg': No such file or directory
# mv: cannot stat 'cat.347.jpg': No such file or directory
# mv: cannot stat 'cat.348.jpg': No such file or directory
# mv: cannot stat 'cat.349.jpg': No such file or directory
# mv: cannot stat 'cat.350.jpg': No such file or directory
# mv: cannot stat 'cat.351.jpg': No such file or directory
# mv: cannot stat 'cat.352.jpg': No such file or directory
# mv: cannot stat 'cat.353.jpg': No such file or directory
# mv: cannot stat 'cat.354.jpg': No such file or directory
# mv: cannot stat 'cat.355.jpg': No such file or directory
# mv: cannot stat 'cat.356.jpg': No such file or directory
# mv: cannot stat 'cat.357.jpg': No such file or directory
# mv: cannot stat 'cat.358.jpg': No such file or directory
# mv: cannot stat 'cat.359.jpg': No such file or directory
# mv: cannot stat 'cat.360.jpg': No such file or directory
# mv: cannot stat 'cat.361.jpg': No such file or directory
# mv: cannot stat 'cat.362.jpg': No such file or directory
# mv: cannot stat 'cat.363.jpg': No such file or directory
# mv: cannot stat 'cat.364.jpg': No such file or directory
# mv: cannot stat 'cat.365.jpg': No such file or directory
# mv: cannot stat 'cat.366.jpg': No such file or directory
# mv: cannot stat 'cat.367.jpg': No such file or directory
# mv: cannot stat 'cat.368.jpg': No such file or directory
# mv: cannot stat 'cat.369.jpg': No such file or directory
# mv: cannot stat 'cat.370.jpg': No such file or directory
# mv: cannot stat 'cat.371.jpg': No such file or directory
# mv: cannot stat 'cat.372.jpg': No such file or directory
# mv: cannot stat 'cat.373.jpg': No such file or directory
# mv: cannot stat 'cat.374.jpg': No such file or directory
# mv: cannot stat 'cat.375.jpg': No such file or directory
# mv: cannot stat 'cat.376.jpg': No such file or directory
# mv: cannot stat 'cat.377.jpg': No such file or directory
# mv: cannot stat 'cat.378.jpg': No such file or directory
# mv: cannot stat 'cat.379.jpg': No such file or directory
# mv: cannot stat 'cat.380.jpg': No such file or directory
# mv: cannot stat 'cat.381.jpg': No such file or directory
# mv: cannot stat 'cat.382.jpg': No such file or directory
# mv: cannot stat 'cat.383.jpg': No such file or directory
# mv: cannot stat 'cat.384.jpg': No such file or directory
# mv: cannot stat 'cat.385.jpg': No such file or directory
# mv: cannot stat 'cat.386.jpg': No such file or directory
# mv: cannot stat 'cat.387.jpg': No such file or directory
# mv: cannot stat 'cat.388.jpg': No such file or directory
# mv: cannot stat 'cat.389.jpg': No such file or directory
# mv: cannot stat 'cat.390.jpg': No such file or directory
# mv: cannot stat 'cat.391.jpg': No such file or directory
# mv: cannot stat 'cat.392.jpg': No such file or directory
# mv: cannot stat 'cat.393.jpg': No such file or directory
# mv: cannot stat 'cat.394.jpg': No such file or directory
# mv: cannot stat 'cat.395.jpg': No such file or directory
# mv: cannot stat 'cat.396.jpg': No such file or directory
# mv: cannot stat 'cat.397.jpg': No such file or directory
# mv: cannot stat 'cat.398.jpg': No such file or directory
# mv: cannot stat 'cat.399.jpg': No such file or directory
# mv: cannot stat 'cat.400.jpg': No such file or directory
# mv: cannot stat 'cat.401.jpg': No such file or directory
# mv: cannot stat 'cat.402.jpg': No such file or directory
# mv: cannot stat 'cat.403.jpg': No such file or directory
# mv: cannot stat 'cat.404.jpg': No such file or directory
# mv: cannot stat 'cat.405.jpg': No such file or directory
# mv: cannot stat 'cat.406.jpg': No such file or directory
# mv: cannot stat 'cat.407.jpg': No such file or directory
# mv: cannot stat 'cat.408.jpg': No such file or directory
# mv: cannot stat 'cat.409.jpg': No such file or directory
# mv: cannot stat 'cat.410.jpg': No such file or directory
# mv: cannot stat 'cat.411.jpg': No such file or directory
# mv: cannot stat 'cat.412.jpg': No such file or directory
# mv: cannot stat 'cat.413.jpg': No such file or directory
# mv: cannot stat 'cat.414.jpg': No such file or directory
# mv: cannot stat 'cat.415.jpg': No such file or directory
# mv: cannot stat 'cat.416.jpg': No such file or directory
# mv: cannot stat 'cat.417.jpg': No such file or directory
# mv: cannot stat 'cat.418.jpg': No such file or directory
# mv: cannot stat 'cat.419.jpg': No such file or directory
# mv: cannot stat 'cat.420.jpg': No such file or directory
# mv: cannot stat 'cat.421.jpg': No such file or directory
# mv: cannot stat 'cat.422.jpg': No such file or directory
# mv: cannot stat 'cat.423.jpg': No such file or directory
# mv: cannot stat 'cat.424.jpg': No such file or directory
# mv: cannot stat 'cat.425.jpg': No such file or directory
# mv: cannot stat 'cat.426.jpg': No such file or directory
# mv: cannot stat 'cat.427.jpg': No such file or directory
# mv: cannot stat 'cat.428.jpg': No such file or directory
# mv: cannot stat 'cat.429.jpg': No such file or directory
# mv: cannot stat 'cat.430.jpg': No such file or directory
# mv: cannot stat 'cat.431.jpg': No such file or directory
# mv: cannot stat 'cat.432.jpg': No such file or directory
# mv: cannot stat 'cat.433.jpg': No such file or directory
# mv: cannot stat 'cat.434.jpg': No such file or directory
# mv: cannot stat 'cat.435.jpg': No such file or directory
# mv: cannot stat 'cat.436.jpg': No such file or directory
# mv: cannot stat 'cat.437.jpg': No such file or directory
# mv: cannot stat 'cat.438.jpg': No such file or directory
# mv: cannot stat 'cat.439.jpg': No such file or directory
# mv: cannot stat 'cat.440.jpg': No such file or directory
# mv: cannot stat 'cat.441.jpg': No such file or directory
# mv: cannot stat 'cat.442.jpg': No such file or directory
# mv: cannot stat 'cat.443.jpg': No such file or directory
# mv: cannot stat 'cat.444.jpg': No such file or directory
# mv: cannot stat 'cat.445.jpg': No such file or directory
# mv: cannot stat 'cat.446.jpg': No such file or directory
# mv: cannot stat 'cat.447.jpg': No such file or directory
# mv: cannot stat 'cat.448.jpg': No such file or directory
# mv: cannot stat 'cat.449.jpg': No such file or directory
# mv: cannot stat 'cat.450.jpg': No such file or directory
# mv: cannot stat 'cat.451.jpg': No such file or directory
# mv: cannot stat 'cat.452.jpg': No such file or directory
# mv: cannot stat 'cat.453.jpg': No such file or directory
# mv: cannot stat 'cat.454.jpg': No such file or directory
# mv: cannot stat 'cat.455.jpg': No such file or directory
# mv: cannot stat 'cat.456.jpg': No such file or directory
# mv: cannot stat 'cat.457.jpg': No such file or directory
# mv: cannot stat 'cat.458.jpg': No such file or directory
# mv: cannot stat 'cat.459.jpg': No such file or directory
# mv: cannot stat 'cat.460.jpg': No such file or directory
# mv: cannot stat 'cat.461.jpg': No such file or directory
# mv: cannot stat 'cat.462.jpg': No such file or directory
# mv: cannot stat 'cat.463.jpg': No such file or directory
# mv: cannot stat 'cat.464.jpg': No such file or directory
# mv: cannot stat 'cat.465.jpg': No such file or directory
# mv: cannot stat 'cat.466.jpg': No such file or directory
# mv: cannot stat 'cat.467.jpg': No such file or directory
# mv: cannot stat 'cat.468.jpg': No such file or directory
# mv: cannot stat 'cat.469.jpg': No such file or directory
# mv: cannot stat 'cat.470.jpg': No such file or directory
# mv: cannot stat 'cat.471.jpg': No such file or directory
# mv: cannot stat 'cat.472.jpg': No such file or directory
# mv: cannot stat 'cat.473.jpg': No such file or directory
# mv: cannot stat 'cat.474.jpg': No such file or directory
# mv: cannot stat 'cat.475.jpg': No such file or directory
# mv: cannot stat 'cat.476.jpg': No such file or directory
# mv: cannot stat 'cat.477.jpg': No such file or directory
# mv: cannot stat 'cat.478.jpg': No such file or directory
# mv: cannot stat 'cat.479.jpg': No such file or directory
# mv: cannot stat 'cat.480.jpg': No such file or directory
# mv: cannot stat 'cat.481.jpg': No such file or directory
# mv: cannot stat 'cat.482.jpg': No such file or directory
# mv: cannot stat 'cat.483.jpg': No such file or directory
# mv: cannot stat 'cat.484.jpg': No such file or directory
# mv: cannot stat 'cat.485.jpg': No such file or directory
# mv: cannot stat 'cat.486.jpg': No such file or directory
# mv: cannot stat 'cat.487.jpg': No such file or directory
# mv: cannot stat 'cat.488.jpg': No such file or directory
# mv: cannot stat 'cat.489.jpg': No such file or directory
# mv: cannot stat 'cat.490.jpg': No such file or directory
# mv: cannot stat 'cat.491.jpg': No such file or directory
# mv: cannot stat 'cat.492.jpg': No such file or directory
# mv: cannot stat 'cat.493.jpg': No such file or directory
# mv: cannot stat 'cat.494.jpg': No such file or directory
# mv: cannot stat 'cat.495.jpg': No such file or directory
# mv: cannot stat 'cat.496.jpg': No such file or directory
# mv: cannot stat 'cat.497.jpg': No such file or directory
# mv: cannot stat 'cat.498.jpg': No such file or directory
# mv: cannot stat 'cat.499.jpg': No such file or directory
# mv: cannot stat 'dog.0.jpg': No such file or directory
# mv: cannot stat 'dog.1.jpg': No such file or directory
# mv: cannot stat 'dog.2.jpg': No such file or directory
# mv: cannot stat 'dog.3.jpg': No such file or directory
# mv: cannot stat 'dog.4.jpg': No such file or directory
# mv: cannot stat 'dog.5.jpg': No such file or directory
# mv: cannot stat 'dog.6.jpg': No such file or directory
# mv: cannot stat 'dog.7.jpg': No such file or directory
# mv: cannot stat 'dog.8.jpg': No such file or directory
# mv: cannot stat 'dog.9.jpg': No such file or directory
# mv: cannot stat 'dog.10.jpg': No such file or directory
# mv: cannot stat 'dog.11.jpg': No such file or directory
# mv: cannot stat 'dog.12.jpg': No such file or directory
# mv: cannot stat 'dog.13.jpg': No such file or directory
# mv: cannot stat 'dog.14.jpg': No such file or directory
# mv: cannot stat 'dog.15.jpg': No such file or directory
# mv: cannot stat 'dog.16.jpg': No such file or directory
# mv: cannot stat 'dog.17.jpg': No such file or directory
# mv: cannot stat 'dog.18.jpg': No such file or directory
# mv: cannot stat 'dog.19.jpg': No such file or directory
# mv: cannot stat 'dog.20.jpg': No such file or directory
# mv: cannot stat 'dog.21.jpg': No such file or directory
# mv: cannot stat 'dog.22.jpg': No such file or directory
# mv: cannot stat 'dog.23.jpg': No such file or directory
# mv: cannot stat 'dog.24.jpg': No such file or directory
# mv: cannot stat 'dog.25.jpg': No such file or directory
# mv: cannot stat 'dog.26.jpg': No such file or directory
# mv: cannot stat 'dog.27.jpg': No such file or directory
# mv: cannot stat 'dog.28.jpg': No such file or directory
# mv: cannot stat 'dog.29.jpg': No such file or directory
# mv: cannot stat 'dog.30.jpg': No such file or directory
# mv: cannot stat 'dog.31.jpg': No such file or directory
# mv: cannot stat 'dog.32.jpg': No such file or directory
# mv: cannot stat 'dog.33.jpg': No such file or directory
# mv: cannot stat 'dog.34.jpg': No such file or directory
# mv: cannot stat 'dog.35.jpg': No such file or directory
# mv: cannot stat 'dog.36.jpg': No such file or directory
# mv: cannot stat 'dog.37.jpg': No such file or directory
# mv: cannot stat 'dog.38.jpg': No such file or directory
# mv: cannot stat 'dog.39.jpg': No such file or directory
# mv: cannot stat 'dog.40.jpg': No such file or directory
# mv: cannot stat 'dog.41.jpg': No such file or directory
# mv: cannot stat 'dog.42.jpg': No such file or directory
# mv: cannot stat 'dog.43.jpg': No such file or directory
# mv: cannot stat 'dog.44.jpg': No such file or directory
# mv: cannot stat 'dog.45.jpg': No such file or directory
# mv: cannot stat 'dog.46.jpg': No such file or directory
# mv: cannot stat 'dog.47.jpg': No such file or directory
# mv: cannot stat 'dog.48.jpg': No such file or directory
# mv: cannot stat 'dog.49.jpg': No such file or directory
# mv: cannot stat 'dog.50.jpg': No such file or directory
# mv: cannot stat 'dog.51.jpg': No such file or directory
# mv: cannot stat 'dog.52.jpg': No such file or directory
# mv: cannot stat 'dog.53.jpg': No such file or directory
# mv: cannot stat 'dog.54.jpg': No such file or directory
# mv: cannot stat 'dog.55.jpg': No such file or directory
# mv: cannot stat 'dog.56.jpg': No such file or directory
# mv: cannot stat 'dog.57.jpg': No such file or directory
# mv: cannot stat 'dog.58.jpg': No such file or directory
# mv: cannot stat 'dog.59.jpg': No such file or directory
# mv: cannot stat 'dog.60.jpg': No such file or directory
# mv: cannot stat 'dog.61.jpg': No such file or directory
# mv: cannot stat 'dog.62.jpg': No such file or directory
# mv: cannot stat 'dog.63.jpg': No such file or directory
# mv: cannot stat 'dog.64.jpg': No such file or directory
# mv: cannot stat 'dog.65.jpg': No such file or directory
# mv: cannot stat 'dog.66.jpg': No such file or directory
# mv: cannot stat 'dog.67.jpg': No such file or directory
# mv: cannot stat 'dog.68.jpg': No such file or directory
# mv: cannot stat 'dog.69.jpg': No such file or directory
# mv: cannot stat 'dog.70.jpg': No such file or directory
# mv: cannot stat 'dog.71.jpg': No such file or directory
# mv: cannot stat 'dog.72.jpg': No such file or directory
# mv: cannot stat 'dog.73.jpg': No such file or directory
# mv: cannot stat 'dog.74.jpg': No such file or directory
# mv: cannot stat 'dog.75.jpg': No such file or directory
# mv: cannot stat 'dog.76.jpg': No such file or directory
# mv: cannot stat 'dog.77.jpg': No such file or directory
# mv: cannot stat 'dog.78.jpg': No such file or directory
# mv: cannot stat 'dog.79.jpg': No such file or directory
# mv: cannot stat 'dog.80.jpg': No such file or directory
# mv: cannot stat 'dog.81.jpg': No such file or directory
# mv: cannot stat 'dog.82.jpg': No such file or directory
# mv: cannot stat 'dog.83.jpg': No such file or directory
# mv: cannot stat 'dog.84.jpg': No such file or directory
# mv: cannot stat 'dog.85.jpg': No such file or directory
# mv: cannot stat 'dog.86.jpg': No such file or directory
# mv: cannot stat 'dog.87.jpg': No such file or directory
# mv: cannot stat 'dog.88.jpg': No such file or directory
# mv: cannot stat 'dog.89.jpg': No such file or directory
# mv: cannot stat 'dog.90.jpg': No such file or directory
# mv: cannot stat 'dog.91.jpg': No such file or directory
# mv: cannot stat 'dog.92.jpg': No such file or directory
# mv: cannot stat 'dog.93.jpg': No such file or directory
# mv: cannot stat 'dog.94.jpg': No such file or directory
# mv: cannot stat 'dog.95.jpg': No such file or directory
# mv: cannot stat 'dog.96.jpg': No such file or directory
# mv: cannot stat 'dog.97.jpg': No such file or directory
# mv: cannot stat 'dog.98.jpg': No such file or directory
# mv: cannot stat 'dog.99.jpg': No such file or directory
# mv: cannot stat 'dog.100.jpg': No such file or directory
# mv: cannot stat 'dog.101.jpg': No such file or directory
# mv: cannot stat 'dog.102.jpg': No such file or directory
# mv: cannot stat 'dog.103.jpg': No such file or directory
# mv: cannot stat 'dog.104.jpg': No such file or directory
# mv: cannot stat 'dog.105.jpg': No such file or directory
# mv: cannot stat 'dog.106.jpg': No such file or directory
# mv: cannot stat 'dog.107.jpg': No such file or directory
# mv: cannot stat 'dog.108.jpg': No such file or directory
# mv: cannot stat 'dog.109.jpg': No such file or directory
# mv: cannot stat 'dog.110.jpg': No such file or directory
# mv: cannot stat 'dog.111.jpg': No such file or directory
# mv: cannot stat 'dog.112.jpg': No such file or directory
# mv: cannot stat 'dog.113.jpg': No such file or directory
# mv: cannot stat 'dog.114.jpg': No such file or directory
# mv: cannot stat 'dog.115.jpg': No such file or directory
# mv: cannot stat 'dog.116.jpg': No such file or directory
# mv: cannot stat 'dog.117.jpg': No such file or directory
# mv: cannot stat 'dog.118.jpg': No such file or directory
# mv: cannot stat 'dog.119.jpg': No such file or directory
# mv: cannot stat 'dog.120.jpg': No such file or directory
# mv: cannot stat 'dog.121.jpg': No such file or directory
# mv: cannot stat 'dog.122.jpg': No such file or directory
# mv: cannot stat 'dog.123.jpg': No such file or directory
# mv: cannot stat 'dog.124.jpg': No such file or directory
# mv: cannot stat 'dog.125.jpg': No such file or directory
# mv: cannot stat 'dog.126.jpg': No such file or directory
# mv: cannot stat 'dog.127.jpg': No such file or directory
# mv: cannot stat 'dog.128.jpg': No such file or directory
# mv: cannot stat 'dog.129.jpg': No such file or directory
# mv: cannot stat 'dog.130.jpg': No such file or directory
# mv: cannot stat 'dog.131.jpg': No such file or directory
# mv: cannot stat 'dog.132.jpg': No such file or directory
# mv: cannot stat 'dog.133.jpg': No such file or directory
# mv: cannot stat 'dog.134.jpg': No such file or directory
# mv: cannot stat 'dog.135.jpg': No such file or directory
# mv: cannot stat 'dog.136.jpg': No such file or directory
# mv: cannot stat 'dog.137.jpg': No such file or directory
# mv: cannot stat 'dog.138.jpg': No such file or directory
# mv: cannot stat 'dog.139.jpg': No such file or directory
# mv: cannot stat 'dog.140.jpg': No such file or directory
# mv: cannot stat 'dog.141.jpg': No such file or directory
# mv: cannot stat 'dog.142.jpg': No such file or directory
# mv: cannot stat 'dog.143.jpg': No such file or directory
# mv: cannot stat 'dog.144.jpg': No such file or directory
# mv: cannot stat 'dog.145.jpg': No such file or directory
# mv: cannot stat 'dog.146.jpg': No such file or directory
# mv: cannot stat 'dog.147.jpg': No such file or directory
# mv: cannot stat 'dog.148.jpg': No such file or directory
# mv: cannot stat 'dog.149.jpg': No such file or directory
# mv: cannot stat 'dog.150.jpg': No such file or directory
# mv: cannot stat 'dog.151.jpg': No such file or directory
# mv: cannot stat 'dog.152.jpg': No such file or directory
# mv: cannot stat 'dog.153.jpg': No such file or directory
# mv: cannot stat 'dog.154.jpg': No such file or directory
# mv: cannot stat 'dog.155.jpg': No such file or directory
# mv: cannot stat 'dog.156.jpg': No such file or directory
# mv: cannot stat 'dog.157.jpg': No such file or directory
# mv: cannot stat 'dog.158.jpg': No such file or directory
# mv: cannot stat 'dog.159.jpg': No such file or directory
# mv: cannot stat 'dog.160.jpg': No such file or directory
# mv: cannot stat 'dog.161.jpg': No such file or directory
# mv: cannot stat 'dog.162.jpg': No such file or directory
# mv: cannot stat 'dog.163.jpg': No such file or directory
# mv: cannot stat 'dog.164.jpg': No such file or directory
# mv: cannot stat 'dog.165.jpg': No such file or directory
# mv: cannot stat 'dog.166.jpg': No such file or directory
# mv: cannot stat 'dog.167.jpg': No such file or directory
# mv: cannot stat 'dog.168.jpg': No such file or directory
# mv: cannot stat 'dog.169.jpg': No such file or directory
# mv: cannot stat 'dog.170.jpg': No such file or directory
# mv: cannot stat 'dog.171.jpg': No such file or directory
# mv: cannot stat 'dog.172.jpg': No such file or directory
# mv: cannot stat 'dog.173.jpg': No such file or directory
# mv: cannot stat 'dog.174.jpg': No such file or directory
# mv: cannot stat 'dog.175.jpg': No such file or directory
# mv: cannot stat 'dog.176.jpg': No such file or directory
# mv: cannot stat 'dog.177.jpg': No such file or directory
# mv: cannot stat 'dog.178.jpg': No such file or directory
# mv: cannot stat 'dog.179.jpg': No such file or directory
# mv: cannot stat 'dog.180.jpg': No such file or directory
# mv: cannot stat 'dog.181.jpg': No such file or directory
# mv: cannot stat 'dog.182.jpg': No such file or directory
# mv: cannot stat 'dog.183.jpg': No such file or directory
# mv: cannot stat 'dog.184.jpg': No such file or directory
# mv: cannot stat 'dog.185.jpg': No such file or directory
# mv: cannot stat 'dog.186.jpg': No such file or directory
# mv: cannot stat 'dog.187.jpg': No such file or directory
# mv: cannot stat 'dog.188.jpg': No such file or directory
# mv: cannot stat 'dog.189.jpg': No such file or directory
# mv: cannot stat 'dog.190.jpg': No such file or directory
# mv: cannot stat 'dog.191.jpg': No such file or directory
# mv: cannot stat 'dog.192.jpg': No such file or directory
# mv: cannot stat 'dog.193.jpg': No such file or directory
# mv: cannot stat 'dog.194.jpg': No such file or directory
# mv: cannot stat 'dog.195.jpg': No such file or directory
# mv: cannot stat 'dog.196.jpg': No such file or directory
# mv: cannot stat 'dog.197.jpg': No such file or directory
# mv: cannot stat 'dog.198.jpg': No such file or directory
# mv: cannot stat 'dog.199.jpg': No such file or directory
# mv: cannot stat 'dog.200.jpg': No such file or directory
# mv: cannot stat 'dog.201.jpg': No such file or directory
# mv: cannot stat 'dog.202.jpg': No such file or directory
# mv: cannot stat 'dog.203.jpg': No such file or directory
# mv: cannot stat 'dog.204.jpg': No such file or directory
# mv: cannot stat 'dog.205.jpg': No such file or directory
# mv: cannot stat 'dog.206.jpg': No such file or directory
# mv: cannot stat 'dog.207.jpg': No such file or directory
# mv: cannot stat 'dog.208.jpg': No such file or directory
# mv: cannot stat 'dog.209.jpg': No such file or directory
# mv: cannot stat 'dog.210.jpg': No such file or directory
# mv: cannot stat 'dog.211.jpg': No such file or directory
# mv: cannot stat 'dog.212.jpg': No such file or directory
# mv: cannot stat 'dog.213.jpg': No such file or directory
# mv: cannot stat 'dog.214.jpg': No such file or directory
# mv: cannot stat 'dog.215.jpg': No such file or directory
# mv: cannot stat 'dog.216.jpg': No such file or directory
# mv: cannot stat 'dog.217.jpg': No such file or directory
# mv: cannot stat 'dog.218.jpg': No such file or directory
# mv: cannot stat 'dog.219.jpg': No such file or directory
# mv: cannot stat 'dog.220.jpg': No such file or directory
# mv: cannot stat 'dog.221.jpg': No such file or directory
# mv: cannot stat 'dog.222.jpg': No such file or directory
# mv: cannot stat 'dog.223.jpg': No such file or directory
# mv: cannot stat 'dog.224.jpg': No such file or directory
# mv: cannot stat 'dog.225.jpg': No such file or directory
# mv: cannot stat 'dog.226.jpg': No such file or directory
# mv: cannot stat 'dog.227.jpg': No such file or directory
# mv: cannot stat 'dog.228.jpg': No such file or directory
# mv: cannot stat 'dog.229.jpg': No such file or directory
# mv: cannot stat 'dog.230.jpg': No such file or directory
# mv: cannot stat 'dog.231.jpg': No such file or directory
# mv: cannot stat 'dog.232.jpg': No such file or directory
# mv: cannot stat 'dog.233.jpg': No such file or directory
# mv: cannot stat 'dog.234.jpg': No such file or directory
# mv: cannot stat 'dog.235.jpg': No such file or directory
# mv: cannot stat 'dog.236.jpg': No such file or directory
# mv: cannot stat 'dog.237.jpg': No such file or directory
# mv: cannot stat 'dog.238.jpg': No such file or directory
# mv: cannot stat 'dog.239.jpg': No such file or directory
# mv: cannot stat 'dog.240.jpg': No such file or directory
# mv: cannot stat 'dog.241.jpg': No such file or directory
# mv: cannot stat 'dog.242.jpg': No such file or directory
# mv: cannot stat 'dog.243.jpg': No such file or directory
# mv: cannot stat 'dog.244.jpg': No such file or directory
# mv: cannot stat 'dog.245.jpg': No such file or directory
# mv: cannot stat 'dog.246.jpg': No such file or directory
# mv: cannot stat 'dog.247.jpg': No such file or directory
# mv: cannot stat 'dog.248.jpg': No such file or directory
# mv: cannot stat 'dog.249.jpg': No such file or directory
# mv: cannot stat 'dog.250.jpg': No such file or directory
# mv: cannot stat 'dog.251.jpg': No such file or directory
# mv: cannot stat 'dog.252.jpg': No such file or directory
# mv: cannot stat 'dog.253.jpg': No such file or directory
# mv: cannot stat 'dog.254.jpg': No such file or directory
# mv: cannot stat 'dog.255.jpg': No such file or directory
# mv: cannot stat 'dog.256.jpg': No such file or directory
# mv: cannot stat 'dog.257.jpg': No such file or directory
# mv: cannot stat 'dog.258.jpg': No such file or directory
# mv: cannot stat 'dog.259.jpg': No such file or directory
# mv: cannot stat 'dog.260.jpg': No such file or directory
# mv: cannot stat 'dog.261.jpg': No such file or directory
# mv: cannot stat 'dog.262.jpg': No such file or directory
# mv: cannot stat 'dog.263.jpg': No such file or directory
# mv: cannot stat 'dog.264.jpg': No such file or directory
# mv: cannot stat 'dog.265.jpg': No such file or directory
# mv: cannot stat 'dog.266.jpg': No such file or directory
# mv: cannot stat 'dog.267.jpg': No such file or directory
# mv: cannot stat 'dog.268.jpg': No such file or directory
# mv: cannot stat 'dog.269.jpg': No such file or directory
# mv: cannot stat 'dog.270.jpg': No such file or directory
# mv: cannot stat 'dog.271.jpg': No such file or directory
# mv: cannot stat 'dog.272.jpg': No such file or directory
# mv: cannot stat 'dog.273.jpg': No such file or directory
# mv: cannot stat 'dog.274.jpg': No such file or directory
# mv: cannot stat 'dog.275.jpg': No such file or directory
# mv: cannot stat 'dog.276.jpg': No such file or directory
# mv: cannot stat 'dog.277.jpg': No such file or directory
# mv: cannot stat 'dog.278.jpg': No such file or directory
# mv: cannot stat 'dog.279.jpg': No such file or directory
# mv: cannot stat 'dog.280.jpg': No such file or directory
# mv: cannot stat 'dog.281.jpg': No such file or directory
# mv: cannot stat 'dog.282.jpg': No such file or directory
# mv: cannot stat 'dog.283.jpg': No such file or directory
# mv: cannot stat 'dog.284.jpg': No such file or directory
# mv: cannot stat 'dog.285.jpg': No such file or directory
# mv: cannot stat 'dog.286.jpg': No such file or directory
# mv: cannot stat 'dog.287.jpg': No such file or directory
# mv: cannot stat 'dog.288.jpg': No such file or directory
# mv: cannot stat 'dog.289.jpg': No such file or directory
# mv: cannot stat 'dog.290.jpg': No such file or directory
# mv: cannot stat 'dog.291.jpg': No such file or directory
# mv: cannot stat 'dog.292.jpg': No such file or directory
# mv: cannot stat 'dog.293.jpg': No such file or directory
# mv: cannot stat 'dog.294.jpg': No such file or directory
# mv: cannot stat 'dog.295.jpg': No such file or directory
# mv: cannot stat 'dog.296.jpg': No such file or directory
# mv: cannot stat 'dog.297.jpg': No such file or directory
# mv: cannot stat 'dog.298.jpg': No such file or directory
# mv: cannot stat 'dog.299.jpg': No such file or directory
# mv: cannot stat 'dog.300.jpg': No such file or directory
# mv: cannot stat 'dog.301.jpg': No such file or directory
# mv: cannot stat 'dog.302.jpg': No such file or directory
# mv: cannot stat 'dog.303.jpg': No such file or directory
# mv: cannot stat 'dog.304.jpg': No such file or directory
# mv: cannot stat 'dog.305.jpg': No such file or directory
# mv: cannot stat 'dog.306.jpg': No such file or directory
# mv: cannot stat 'dog.307.jpg': No such file or directory
# mv: cannot stat 'dog.308.jpg': No such file or directory
# mv: cannot stat 'dog.309.jpg': No such file or directory
# mv: cannot stat 'dog.310.jpg': No such file or directory
# mv: cannot stat 'dog.311.jpg': No such file or directory
# mv: cannot stat 'dog.312.jpg': No such file or directory
# mv: cannot stat 'dog.313.jpg': No such file or directory
# mv: cannot stat 'dog.314.jpg': No such file or directory
# mv: cannot stat 'dog.315.jpg': No such file or directory
# mv: cannot stat 'dog.316.jpg': No such file or directory
# mv: cannot stat 'dog.317.jpg': No such file or directory
# mv: cannot stat 'dog.318.jpg': No such file or directory
# mv: cannot stat 'dog.319.jpg': No such file or directory
# mv: cannot stat 'dog.320.jpg': No such file or directory
# mv: cannot stat 'dog.321.jpg': No such file or directory
# mv: cannot stat 'dog.322.jpg': No such file or directory
# mv: cannot stat 'dog.323.jpg': No such file or directory
# mv: cannot stat 'dog.324.jpg': No such file or directory
# mv: cannot stat 'dog.325.jpg': No such file or directory
# mv: cannot stat 'dog.326.jpg': No such file or directory
# mv: cannot stat 'dog.327.jpg': No such file or directory
# mv: cannot stat 'dog.328.jpg': No such file or directory
# mv: cannot stat 'dog.329.jpg': No such file or directory
# mv: cannot stat 'dog.330.jpg': No such file or directory
# mv: cannot stat 'dog.331.jpg': No such file or directory
# mv: cannot stat 'dog.332.jpg': No such file or directory
# mv: cannot stat 'dog.333.jpg': No such file or directory
# mv: cannot stat 'dog.334.jpg': No such file or directory
# mv: cannot stat 'dog.335.jpg': No such file or directory
# mv: cannot stat 'dog.336.jpg': No such file or directory
# mv: cannot stat 'dog.337.jpg': No such file or directory
# mv: cannot stat 'dog.338.jpg': No such file or directory
# mv: cannot stat 'dog.339.jpg': No such file or directory
# mv: cannot stat 'dog.340.jpg': No such file or directory
# mv: cannot stat 'dog.341.jpg': No such file or directory
# mv: cannot stat 'dog.342.jpg': No such file or directory
# mv: cannot stat 'dog.343.jpg': No such file or directory
# mv: cannot stat 'dog.344.jpg': No such file or directory
# mv: cannot stat 'dog.345.jpg': No such file or directory
# mv: cannot stat 'dog.346.jpg': No such file or directory
# mv: cannot stat 'dog.347.jpg': No such file or directory
# mv: cannot stat 'dog.348.jpg': No such file or directory
# mv: cannot stat 'dog.349.jpg': No such file or directory
# mv: cannot stat 'dog.350.jpg': No such file or directory
# mv: cannot stat 'dog.351.jpg': No such file or directory
# mv: cannot stat 'dog.352.jpg': No such file or directory
# mv: cannot stat 'dog.353.jpg': No such file or directory
# mv: cannot stat 'dog.354.jpg': No such file or directory
# mv: cannot stat 'dog.355.jpg': No such file or directory
# mv: cannot stat 'dog.356.jpg': No such file or directory
# mv: cannot stat 'dog.357.jpg': No such file or directory
# mv: cannot stat 'dog.358.jpg': No such file or directory
# mv: cannot stat 'dog.359.jpg': No such file or directory
# mv: cannot stat 'dog.360.jpg': No such file or directory
# mv: cannot stat 'dog.361.jpg': No such file or directory
# mv: cannot stat 'dog.362.jpg': No such file or directory
# mv: cannot stat 'dog.363.jpg': No such file or directory
# mv: cannot stat 'dog.364.jpg': No such file or directory
# mv: cannot stat 'dog.365.jpg': No such file or directory
# mv: cannot stat 'dog.366.jpg': No such file or directory
# mv: cannot stat 'dog.367.jpg': No such file or directory
# mv: cannot stat 'dog.368.jpg': No such file or directory
# mv: cannot stat 'dog.369.jpg': No such file or directory
# mv: cannot stat 'dog.370.jpg': No such file or directory
# mv: cannot stat 'dog.371.jpg': No such file or directory
# mv: cannot stat 'dog.372.jpg': No such file or directory
# mv: cannot stat 'dog.373.jpg': No such file or directory
# mv: cannot stat 'dog.374.jpg': No such file or directory
# mv: cannot stat 'dog.375.jpg': No such file or directory
# mv: cannot stat 'dog.376.jpg': No such file or directory
# mv: cannot stat 'dog.377.jpg': No such file or directory
# mv: cannot stat 'dog.378.jpg': No such file or directory
# mv: cannot stat 'dog.379.jpg': No such file or directory
# mv: cannot stat 'dog.380.jpg': No such file or directory
# mv: cannot stat 'dog.381.jpg': No such file or directory
# mv: cannot stat 'dog.382.jpg': No such file or directory
# mv: cannot stat 'dog.383.jpg': No such file or directory
# mv: cannot stat 'dog.384.jpg': No such file or directory
# mv: cannot stat 'dog.385.jpg': No such file or directory
# mv: cannot stat 'dog.386.jpg': No such file or directory
# mv: cannot stat 'dog.387.jpg': No such file or directory
# mv: cannot stat 'dog.388.jpg': No such file or directory
# mv: cannot stat 'dog.389.jpg': No such file or directory
# mv: cannot stat 'dog.390.jpg': No such file or directory
# mv: cannot stat 'dog.391.jpg': No such file or directory
# mv: cannot stat 'dog.392.jpg': No such file or directory
# mv: cannot stat 'dog.393.jpg': No such file or directory
# mv: cannot stat 'dog.394.jpg': No such file or directory
# mv: cannot stat 'dog.395.jpg': No such file or directory
# mv: cannot stat 'dog.396.jpg': No such file or directory
# mv: cannot stat 'dog.397.jpg': No such file or directory
# mv: cannot stat 'dog.398.jpg': No such file or directory
# mv: cannot stat 'dog.399.jpg': No such file or directory
# mv: cannot stat 'dog.400.jpg': No such file or directory
# mv: cannot stat 'dog.401.jpg': No such file or directory
# mv: cannot stat 'dog.402.jpg': No such file or directory
# mv: cannot stat 'dog.403.jpg': No such file or directory
# mv: cannot stat 'dog.404.jpg': No such file or directory
# mv: cannot stat 'dog.405.jpg': No such file or directory
# mv: cannot stat 'dog.406.jpg': No such file or directory
# mv: cannot stat 'dog.407.jpg': No such file or directory
# mv: cannot stat 'dog.408.jpg': No such file or directory
# mv: cannot stat 'dog.409.jpg': No such file or directory
# mv: cannot stat 'dog.410.jpg': No such file or directory
# mv: cannot stat 'dog.411.jpg': No such file or directory
# mv: cannot stat 'dog.412.jpg': No such file or directory
# mv: cannot stat 'dog.413.jpg': No such file or directory
# mv: cannot stat 'dog.414.jpg': No such file or directory
# mv: cannot stat 'dog.415.jpg': No such file or directory
# mv: cannot stat 'dog.416.jpg': No such file or directory
# mv: cannot stat 'dog.417.jpg': No such file or directory
# mv: cannot stat 'dog.418.jpg': No such file or directory
# mv: cannot stat 'dog.419.jpg': No such file or directory
# mv: cannot stat 'dog.420.jpg': No such file or directory
# mv: cannot stat 'dog.421.jpg': No such file or directory
# mv: cannot stat 'dog.422.jpg': No such file or directory
# mv: cannot stat 'dog.423.jpg': No such file or directory
# mv: cannot stat 'dog.424.jpg': No such file or directory
# mv: cannot stat 'dog.425.jpg': No such file or directory
# mv: cannot stat 'dog.426.jpg': No such file or directory
# mv: cannot stat 'dog.427.jpg': No such file or directory
# mv: cannot stat 'dog.428.jpg': No such file or directory
# mv: cannot stat 'dog.429.jpg': No such file or directory
# mv: cannot stat 'dog.430.jpg': No such file or directory
# mv: cannot stat 'dog.431.jpg': No such file or directory
# mv: cannot stat 'dog.432.jpg': No such file or directory
# mv: cannot stat 'dog.433.jpg': No such file or directory
# mv: cannot stat 'dog.434.jpg': No such file or directory
# mv: cannot stat 'dog.435.jpg': No such file or directory
# mv: cannot stat 'dog.436.jpg': No such file or directory
# mv: cannot stat 'dog.437.jpg': No such file or directory
# mv: cannot stat 'dog.438.jpg': No such file or directory
# mv: cannot stat 'dog.439.jpg': No such file or directory
# mv: cannot stat 'dog.440.jpg': No such file or directory
# mv: cannot stat 'dog.441.jpg': No such file or directory
# mv: cannot stat 'dog.442.jpg': No such file or directory
# mv: cannot stat 'dog.443.jpg': No such file or directory
# mv: cannot stat 'dog.444.jpg': No such file or directory
# mv: cannot stat 'dog.445.jpg': No such file or directory
# mv: cannot stat 'dog.446.jpg': No such file or directory
# mv: cannot stat 'dog.447.jpg': No such file or directory
# mv: cannot stat 'dog.448.jpg': No such file or directory
# mv: cannot stat 'dog.449.jpg': No such file or directory
# mv: cannot stat 'dog.450.jpg': No such file or directory
# mv: cannot stat 'dog.451.jpg': No such file or directory
# mv: cannot stat 'dog.452.jpg': No such file or directory
# mv: cannot stat 'dog.453.jpg': No such file or directory
# mv: cannot stat 'dog.454.jpg': No such file or directory
# mv: cannot stat 'dog.455.jpg': No such file or directory
# mv: cannot stat 'dog.456.jpg': No such file or directory
# mv: cannot stat 'dog.457.jpg': No such file or directory
# mv: cannot stat 'dog.458.jpg': No such file or directory
# mv: cannot stat 'dog.459.jpg': No such file or directory
# mv: cannot stat 'dog.460.jpg': No such file or directory
# mv: cannot stat 'dog.461.jpg': No such file or directory
# mv: cannot stat 'dog.462.jpg': No such file or directory
# mv: cannot stat 'dog.463.jpg': No such file or directory
# mv: cannot stat 'dog.464.jpg': No such file or directory
# mv: cannot stat 'dog.465.jpg': No such file or directory
# mv: cannot stat 'dog.466.jpg': No such file or directory
# mv: cannot stat 'dog.467.jpg': No such file or directory
# mv: cannot stat 'dog.468.jpg': No such file or directory
# mv: cannot stat 'dog.469.jpg': No such file or directory
# mv: cannot stat 'dog.470.jpg': No such file or directory
# mv: cannot stat 'dog.471.jpg': No such file or directory
# mv: cannot stat 'dog.472.jpg': No such file or directory
# mv: cannot stat 'dog.473.jpg': No such file or directory
# mv: cannot stat 'dog.474.jpg': No such file or directory
# mv: cannot stat 'dog.475.jpg': No such file or directory
# mv: cannot stat 'dog.476.jpg': No such file or directory
# mv: cannot stat 'dog.477.jpg': No such file or directory
# mv: cannot stat 'dog.478.jpg': No such file or directory
# mv: cannot stat 'dog.479.jpg': No such file or directory
# mv: cannot stat 'dog.480.jpg': No such file or directory
# mv: cannot stat 'dog.481.jpg': No such file or directory
# mv: cannot stat 'dog.482.jpg': No such file or directory
# mv: cannot stat 'dog.483.jpg': No such file or directory
# mv: cannot stat 'dog.484.jpg': No such file or directory
# mv: cannot stat 'dog.485.jpg': No such file or directory
# mv: cannot stat 'dog.486.jpg': No such file or directory
# mv: cannot stat 'dog.487.jpg': No such file or directory
# mv: cannot stat 'dog.488.jpg': No such file or directory
# mv: cannot stat 'dog.489.jpg': No such file or directory
# mv: cannot stat 'dog.490.jpg': No such file or directory
# mv: cannot stat 'dog.491.jpg': No such file or directory
# mv: cannot stat 'dog.492.jpg': No such file or directory
# mv: cannot stat 'dog.493.jpg': No such file or directory
# mv: cannot stat 'dog.494.jpg': No such file or directory
# mv: cannot stat 'dog.495.jpg': No such file or directory
# mv: cannot stat 'dog.496.jpg': No such file or directory
# mv: cannot stat 'dog.497.jpg': No such file or directory
# mv: cannot stat 'dog.498.jpg': No such file or directory
# mv: cannot stat 'dog.499.jpg': No such file or directory

# %% [markdown]
# Most of the pretrained models require the input to be 224x224 images. Also, we'll need to match the normalization used when the models were trained. Each color channel was normalized separately, the means are `[0.485, 0.456, 0.406]` and the standard deviations are `[0.229, 0.224, 0.225]`.

# %%
data_dir = 'assets/Cat_Dog_data'

# TODO: Define transforms for the training data and testing data
train_transforms = transforms.Compose([transforms.RandomRotation(30),
                                       transforms.RandomResizedCrop(224),
                                       transforms.RandomHorizontalFlip(),
                                       transforms.ToTensor(),
                                       transforms.Normalize([0.485, 0.456, 0.406],
                                                            [0.229, 0.224, 0.225])])

test_transforms = transforms.Compose([transforms.Resize(255),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406],
                                                            [0.229, 0.224, 0.225])])

# Pass transforms in here, then run the next cell to see how the transforms look
train_data = datasets.ImageFolder(data_dir + '/train', transform=train_transforms)
test_data = datasets.ImageFolder(data_dir + '/test', transform=test_transforms)

trainloader = torch.utils.data.DataLoader(train_data, batch_size=64, shuffle=True)
testloader = torch.utils.data.DataLoader(test_data, batch_size=64)

# %% [markdown]
# We can load in a model such as [DenseNet](http://pytorch.org/docs/0.3.0/torchvision/models.html#id5). Let's print out the model architecture so we can see what's going on.

# %%
model = models.densenet121(pretrained=True)
model
# Out:
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to C:\Users\ravij/.cache\torch\checkpoints\densenet121-a639ec97.pth
# 100%|█████████████████████████████████████████████████████████████████████████████| 30.8M/30.8M [00:04<00:00, 7.53MB/s]
# DenseNet(
#   (features): Sequential(
#     (conv0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu0): ReLU(inplace=True)
#     (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (denseblock1): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition1): _Transition(
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock2): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition2): _Transition(
#       (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock3): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer17): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer18): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer19): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer20): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer21): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer22): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer23): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer24): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition3): _Transition(
#       (norm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock4): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (norm5): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Linear(in_features=1024, out_features=1000, bias=True)
# )

# %% [markdown]
# This model is built out of two main parts, the features and the classifier. The features part is a stack of convolutional layers and overall works as a feature detector that can be fed into a classifier. The classifier part is a single fully-connected layer `(classifier): Linear(in_features=1024, out_features=1000)`. This layer was trained on the ImageNet dataset, so it won't work for our specific problem. That means we need to replace the classifier, but the features will work perfectly on their own. In general, I think about pre-trained networks as amazingly good feature detectors that can be used as the input for simple feed-forward classifiers.

# %%
# Freeze parameters so we don't backprop through them
for param in model.parameters():
    param.requires_grad = False

from collections import OrderedDict
classifier = nn.Sequential(OrderedDict([
                          ('fc1', nn.Linear(1024, 500)),
                          ('relu', nn.ReLU()),
                          ('fc2', nn.Linear(500, 2)),
                          ('output', nn.LogSoftmax(dim=1))
                          ]))
    
model.classifier = classifier

# %% [markdown]
# With our model built, we need to train the classifier. However, now we're using a **really deep** neural network. If you try to train this on a CPU like normal, it will take a long, long time. Instead, we're going to use the GPU to do the calculations. The linear algebra computations are done in parallel on the GPU leading to 100x increased training speeds. It's also possible to train on multiple GPUs, further decreasing training time.
#
# PyTorch, along with pretty much every other deep learning framework, uses [CUDA](https://developer.nvidia.com/cuda-zone) to efficiently compute the forward and backwards passes on the GPU. In PyTorch, you move your model parameters and other tensors to the GPU memory using `model.to('cuda')`. You can move them back from the GPU with `model.to('cpu')` which you'll commonly do when you need to operate on the network output outside of PyTorch. As a demonstration of the increased speed, I'll compare how long it takes to perform a forward and backward pass with and without a GPU.

# %%
import time

# %%
for device in ['cpu', 'cuda']:

    criterion = nn.NLLLoss()
    # Only train the classifier parameters, feature parameters are frozen
    optimizer = optim.Adam(model.classifier.parameters(), lr=0.001)

    model.to(device)

    for ii, (inputs, labels) in enumerate(trainloader):

        # Move input and label tensors to the GPU
        inputs, labels = inputs.to(device), labels.to(device)

        start = time.time()

        outputs = model.forward(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        if ii==3:
            break
        
    print(f"Device = {device}; Time per batch: {(time.time() - start)/3:.3f} seconds")

# %% [markdown]
# You can write device agnostic code which will automatically use CUDA if it's enabled like so:
# ```python
# # at beginning of the script
# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#
# ...
#
# # then whenever you get a new Tensor or Module
# # this won't copy if they are already on the desired device
# input = data.to(device)
# model = MyModule(...).to(device)
# ```
#
# From here, I'll let you finish training the model. The process is the same as before except now your model is much more powerful. You should get better than 95% accuracy easily.
#
# >**Exercise:** Train a pretrained models to classify the cat and dog images. Continue with the DenseNet model, or try ResNet, it's also a good model to try out first. Make sure you are only training the classifier and the parameters for the features part are frozen.

# %%
## TODO: Use a pretrained model to classify the cat and dog images
